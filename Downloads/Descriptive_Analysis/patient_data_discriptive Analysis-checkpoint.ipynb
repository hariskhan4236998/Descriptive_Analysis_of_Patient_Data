# %%
import pandas as pd

# %%
data = pd.read_csv("patient_diabetes_unclean.csv")

# %%
data
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 1      0.6  23.0     N
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1009 non-null   int64
#  1   No_Pation  1009 non-null   int64
#  2   Gender     1009 non-null   object
#  3   AGE        1008 non-null   float64
#  4   Urea       1008 non-null   float64
#  5   Cr         1007 non-null   float64
#  6   HbA1c      1006 non-null   float64
#  7   Chol       1007 non-null   float64
#  8   TG         1007 non-null   float64
#  9   HDL        1008 non-null   float64
#  10  LDL        1007 non-null   float64
#  11  VLDL       1008 non-null   float64
#  12  BMI        1009 non-null   float64
#  13  CLASS      1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB
# None

# %%
print(data.isnull().sum())
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
print(data.describe())
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1009.000000  1.009000e+03  1008.000000  1008.000000  1007.000000
# mean    339.161546  2.717448e+05    53.620040     5.131094    68.973188
# std     239.738169  3.365681e+06     8.740975     2.931136    59.813297
# min       1.000000  1.230000e+02    25.000000     0.500000     6.000000
# 25%     127.000000  2.406500e+04    51.000000     3.700000    48.000000
# 50%     296.000000  3.439900e+04    55.000000     4.600000    60.000000
# 75%     548.000000  4.539000e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1006.000000  1007.000000  1007.000000  1008.000000  1007.000000
# mean      8.284155     4.863873     2.348769     1.204216     2.610119
# std       2.533576     1.297326     1.397487     0.658158     1.116095
# ...

# %% [markdown]
# Data Cleaning

# %%
data.loc[:, 'Urea'] = data['Urea'].fillna(data['Urea'].mean())

# %%
print(data['Gender'].value_counts())
print(data['CLASS'].value_counts())
# Out:
# Gender
# M    563
# F    432
# Name: count, dtype: int64
# CLASS
# Y     830
# N     102
# P      53
# Y       9
# N       1
# Name: count, dtype: int64

# %%
data = data.dropna()

# %%
data.loc[:, 'Gender'] = data['Gender'].str.upper()

# %% [markdown]
#  Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Visualize Categorical Data

# %%
sns.countplot(x='Gender', data=data)        #Bar plot for Gender distribution
plt.title('Gender Distribution')
plt.show()

# %%
sns.countplot(x='CLASS', data=data)        #Bar plot for CLASS distribution
plt.title('CLASS Distribution')
plt.show()

# %% [markdown]
# Visualize Numerical Data

# %%
sns.boxplot(x='CLASS', y='AGE', data=data)       # Box plot for AGE grouped by CLASS
plt.title('Age Distribution by CLASS')
plt.show()

# %%
data['BMI'].hist(bins=20)                  # Histogram for BMI
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  Correlation Heatmap

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
corr = numeric_data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Advanced Insights

# %%
sns.scatterplot(x='Urea', y='HbA1c', hue='CLASS', data=data)
plt.title('Relationship between Urea and HbA1c')
plt.show()

# %%
sns.pairplot(data, hue='CLASS')
plt.show()

# %%
data.to_csv('cleaned_data.csv', index=False)

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df
# Out:
#       ID  No_Pation  Gender   AGE       Urea     Cr  HbA1c  Chol   TG  HDL  \
# 0    502      17975       0  50.0   4.700000   46.0    4.9   4.2  0.9  2.4
# 1    735      34221       1  26.0   4.500000   62.0    4.9   3.7  1.4  1.1
# 2    420      47975       0  50.0   4.700000   46.0    4.9   4.2  0.9  2.4
# 3    680      87656       0  50.0   4.700000   46.0    4.9   4.2  0.9  2.4
# 4    504      34223       1  33.0   7.100000   46.0    4.9   4.9  1.0  0.8
# ..   ...        ...     ...   ...        ...    ...    ...   ...  ...  ...
# 990  188     454316       0  75.0  10.300000  113.0    8.6   4.2  1.6  0.9
# 991  189     454316       1  58.0   4.000000   55.0    7.9   4.9  2.0  1.2
# 992  191     454316       1  55.0   5.131094   62.0    6.8   5.3  2.0  1.0
# 993  194     454316       0  57.0   4.100000   70.0    9.3   5.3  3.3  1.0
# 994  195       4543       0  55.0   4.100000   34.0   13.9   5.4  1.6  1.6
#
#      LDL  VLDL   BMI CLASS
# 0    1.4   0.5  24.0     N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         995 non-null    int64
#  1   No_Pation  995 non-null    int64
#  2   Gender     995 non-null    int64
#  3   AGE        995 non-null    float64
#  4   Urea       995 non-null    float64
#  5   Cr         995 non-null    float64
#  6   HbA1c      995 non-null    float64
#  7   Chol       995 non-null    float64
#  8   TG         995 non-null    float64
#  9   HDL        995 non-null    float64
#  10  LDL        995 non-null    float64
#  11  VLDL       995 non-null    float64
#  12  BMI        995 non-null    float64
#  13  CLASS      995 non-null    object
# dtypes: float64(10), int64(3), object(1)
# memory usage: 109.0+ KB
